# %%
import pandas as pd
data = pd.read_csv("D:\\workspace\\DataSet\\Covid\\Covid_India.csv")
df = pd.DataFrame(data)
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10747       0       10618
# 1                             Andhra Pradesh      2339078       7     2324338
# 2                          Arunachal Pradesh        66891       0       66595
# 3                                      Assam       746100       0      738065
# 4                                      Bihar       851404       1      839100
# 5                                 Chandigarh        99358       3       98174
# 6                               Chhattisgarh      1177768       8     1163614
# 7   Dadra and Nagar Haveli and Daman and Diu        11591       0       11587
# 8                                      Delhi      2007313      10     1980781
# 9                                        Goa       259110      15      255082
# 10                                   Gujarat      1277615      11     1266561
# ...

# %%
di = {"Name":["Nani","Remo","Nikky"],"RollNo":[1,2,3],"Percentage":[85,80,99]}
df1 = pd.DataFrame(di)
df1
# Out:
#     Name  RollNo  Percentage
# 0   Nani       1          85
# 1   Remo       2          80
# 2  Nikky       3          99

# %%
dt = [("Nani","Remo","Nikky"),(1,2,3),(85,80,99)]
df2 = pd.DataFrame(dt)
df2
# Out:
#       0     1      2
# 0  Nani  Remo  Nikky
# 1     1     2      3
# 2    85    80     99

# %%
import pandas as pd
data = pd.read_csv("D:\\workspace\\DataSet\\Covid\\Covid_India.csv")
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10747       0       10618     129           0.0
# 1       Andhra Pradesh      2339078       7     2324338   14733           0.0
# 2    Arunachal Pradesh        66891       0       66595     296           0.0
# 3                Assam       746100       0      738065    8035           0.0
# 4                Bihar       851404       1      839100   12303           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.55         1.45    40100376

# %%
df.head(10)
# Out:
#                                   State/UTs  Total Cases  Active  Discharged  \
# 0                       Andaman and Nicobar        10747       0       10618
# 1                            Andhra Pradesh      2339078       7     2324338
# 2                         Arunachal Pradesh        66891       0       66595
# 3                                     Assam       746100       0      738065
# 4                                     Bihar       851404       1      839100
# 5                                Chandigarh        99358       3       98174
# 6                              Chhattisgarh      1177768       8     1163614
# 7  Dadra and Nagar Haveli and Daman and Diu        11591       0       11587
# 8                                     Delhi      2007313      10     1980781
# 9                                       Goa       259110      15      255082
#
#    Deaths  Active Ratio  Discharge Ratio  Death Ratio  Population
# ...

# %%
df.tail()
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 31      Telengana       841453      27      837315    4111           0.0
# 32        Tripura       108034       0      107094     940           0.0
# 33  Uttar Pradesh      2128154      18     2104502   23634           0.0
# 34    Uttarakhand       449429      11      441665    7753           0.0
# 35    West Bengal      2118696      50     2097114   21532           0.0
#
#     Discharge Ratio  Death Ratio  Population
# 31            99.51         0.49    69599762
# 32            99.13         0.87     1646050
# 33            98.89         1.11     1158040
# 34            98.27         1.73    85002417
# 35            98.98         1.02    32199722

# %%
df.tail(3)
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 33  Uttar Pradesh      2128154      18     2104502   23634           0.0
# 34    Uttarakhand       449429      11      441665    7753           0.0
# 35    West Bengal      2118696      50     2097114   21532           0.0
#
#     Discharge Ratio  Death Ratio  Population
# 33            98.89         1.11     1158040
# 34            98.27         1.73    85002417
# 35            98.98         1.02    32199722

# %%
df.describe()
# Out:
#         Total Cases       Active    Discharged         Deaths  Active Ratio  \
# count  3.600000e+01    36.000000  3.600000e+01      36.000000     36.000000
# mean   1.241145e+06    56.527778  1.226346e+06   14742.388889      0.002222
# std    1.834031e+06   215.847762  1.808252e+06   27170.089767      0.007601
# min    1.074700e+04     0.000000  1.061800e+04       4.000000      0.000000
# 25%    1.058650e+05     0.000000  1.048640e+05    1120.750000      0.000000
# 50%    6.127720e+05     7.500000  6.063570e+05    6542.000000      0.000000
# 75%    1.320822e+06    27.500000  1.311256e+06   14292.750000      0.000000
# max    8.136945e+06  1300.000000  7.988392e+06  148419.000000      0.040000
#
#        Discharge Ratio  Death Ratio    Population
# count        36.000000    36.000000  3.600000e+01
# mean         98.893333     1.103889  3.971861e+07
# std           0.498764     0.498479  5.050913e+07
# min          97.540000     0.030000  6.600100e+04
# ...

# %%
df.shape
# Out:
# (36, 9)

# %%
df[0:10:2]
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10747       0       10618     129           0.0
# 2    Arunachal Pradesh        66891       0       66595     296           0.0
# 4                Bihar       851404       1      839100   12303           0.0
# 6         Chhattisgarh      1177768       8     1163614   14146           0.0
# 8                Delhi      2007313      10     1980781   26522           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 2            99.56         0.44      658019
# 4            98.55         1.45    40100376
# 6            98.80         1.20    28900667
# 8            98.68         1.32      773997

# %%
df["State/UTs"]
# Out:
# 0                          Andaman and Nicobar
# 1                               Andhra Pradesh
# 2                            Arunachal Pradesh
# 3                                        Assam
# 4                                        Bihar
# 5                                   Chandigarh
# 6                                 Chhattisgarh
# 7     Dadra and Nagar Haveli and Daman and Diu
# 8                                        Delhi
# 9                                          Goa
# 10                                     Gujarat
# 11                                     Haryana
# 12                            Himachal Pradesh
# 13                           Jammu and Kashmir
# 14                                   Jharkhand
# 15                                   Karnataka
# 16                                      Kerala
# 17                                      Ladakh
# 18                                 Lakshadweep
# 19                              Madhya Pradesh
# ...

# %%
df[["State/UTs","Total Cases"]]
# Out:
#                                    State/UTs  Total Cases
# 0                        Andaman and Nicobar        10747
# 1                             Andhra Pradesh      2339078
# 2                          Arunachal Pradesh        66891
# 3                                      Assam       746100
# 4                                      Bihar       851404
# 5                                 Chandigarh        99358
# 6                               Chhattisgarh      1177768
# 7   Dadra and Nagar Haveli and Daman and Diu        11591
# 8                                      Delhi      2007313
# 9                                        Goa       259110
# 10                                   Gujarat      1277615
# 11                                   Haryana      1056655
# 12                          Himachal Pradesh       312692
# 13                         Jammu and Kashmir       479444
# 14                                 Jharkhand       442574
# ...

# %%
df[["State/UTs","Total Cases"]][0:10:2]
# Out:
#              State/UTs  Total Cases
# 0  Andaman and Nicobar        10747
# 2    Arunachal Pradesh        66891
# 4                Bihar       851404
# 6         Chhattisgarh      1177768
# 8                Delhi      2007313

# %%
for rec in df.iterrows():
    print(rec)
# Out:
# (0, State/UTs          Andaman and Nicobar
# Total Cases                      10747
# Active                               0
# Discharged                       10618
# Deaths                             129
# Active Ratio                       0.0
# Discharge Ratio                   98.8
# Death Ratio                        1.2
# Population                   100896618
# Name: 0, dtype: object)
# (1, State/UTs          Andhra Pradesh
# Total Cases               2339078
# Active                          7
# Discharged                2324338
# Deaths                      14733
# Active Ratio                  0.0
# Discharge Ratio             99.37
# Death Ratio                  0.63
# Population              128500364
# Name: 1, dtype: object)
# (2, State/UTs          Arunachal Pradesh
# Total Cases                    66891
# Active                             0
# Discharged                     66595
# Deaths                           296
# Active Ratio                     0.0
# ...

# %%
df.loc[1]
# Out:
# State/UTs          Andhra Pradesh
# Total Cases               2339078
# Active                          7
# Discharged                2324338
# Deaths                      14733
# Active Ratio                  0.0
# Discharge Ratio             99.37
# Death Ratio                  0.63
# Population              128500364
# Name: 1, dtype: object

# %%
df.loc[1,"Active"]
# Out:
# 7

# %%
df.loc[1:4]
# Out:
#            State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1     Andhra Pradesh      2339078       7     2324338   14733           0.0
# 2  Arunachal Pradesh        66891       0       66595     296           0.0
# 3              Assam       746100       0      738065    8035           0.0
# 4              Bihar       851404       1      839100   12303           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.55         1.45    40100376

# %%
df.loc[1:4,"Total Cases":"Discharge Ratio"]
# Out:
#    Total Cases  Active  Discharged  Deaths  Active Ratio  Discharge Ratio
# 1      2339078       7     2324338   14733           0.0            99.37
# 2        66891       0       66595     296           0.0            99.56
# 3       746100       0      738065    8035           0.0            98.92
# 4       851404       1      839100   12303           0.0            98.55

# %%
df.loc[1:4,["Active","Deaths"]]
# Out:
#    Active  Deaths
# 1       7   14733
# 2       0     296
# 3       0    8035
# 4       1   12303

# %%
df.iloc[1]
# Out:
# State/UTs          Andhra Pradesh
# Total Cases               2339078
# Active                          7
# Discharged                2324338
# Deaths                      14733
# Active Ratio                  0.0
# Discharge Ratio             99.37
# Death Ratio                  0.63
# Population              128500364
# Name: 1, dtype: object

# %%
df.iloc[1:5]
# Out:
#            State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1     Andhra Pradesh      2339078       7     2324338   14733           0.0
# 2  Arunachal Pradesh        66891       0       66595     296           0.0
# 3              Assam       746100       0      738065    8035           0.0
# 4              Bihar       851404       1      839100   12303           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.55         1.45    40100376

# %%
df.iloc[3,0]
# Out:
# 'Assam'

# %%
df.iloc[0:5,0]
# Out:
# 0    Andaman and Nicobar
# 1         Andhra Pradesh
# 2      Arunachal Pradesh
# 3                  Assam
# 4                  Bihar
# Name: State/UTs, dtype: object

# %%
df.iloc[1:5,0:5]
# Out:
#            State/UTs  Total Cases  Active  Discharged  Deaths
# 1     Andhra Pradesh      2339078       7     2324338   14733
# 2  Arunachal Pradesh        66891       0       66595     296
# 3              Assam       746100       0      738065    8035
# 4              Bihar       851404       1      839100   12303

# %%
df.iloc[[1,2,3,4,5]]
# Out:
#            State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1     Andhra Pradesh      2339078       7     2324338   14733           0.0
# 2  Arunachal Pradesh        66891       0       66595     296           0.0
# 3              Assam       746100       0      738065    8035           0.0
# 4              Bihar       851404       1      839100   12303           0.0
# 5         Chandigarh        99358       3       98174    1181           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.55         1.45    40100376
# 5            98.81         1.19    30501026

# %%
df.iloc[[0,11,9,4,6]]
# Out:
#               State/UTs  Total Cases  Active  Discharged  Deaths  \
# 0   Andaman and Nicobar        10747       0       10618     129
# 11              Haryana      1056655      38     1045903   10714
# 9                   Goa       259110      15      255082    4013
# 4                 Bihar       851404       1      839100   12303
# 6          Chhattisgarh      1177768       8     1163614   14146
#
#     Active Ratio  Discharge Ratio  Death Ratio  Population
# 0           0.00            98.80         1.20   100896618
# 11          0.00            98.98         1.01     7503010
# 9           0.01            98.45         1.55     3772103
# 4           0.00            98.55         1.45    40100376
# 6           0.00            98.80         1.20    28900667

# %%
df.iloc[:,[1,2,3,4]]
# Out:
#     Total Cases  Active  Discharged  Deaths
# 0         10747       0       10618     129
# 1       2339078       7     2324338   14733
# 2         66891       0       66595     296
# 3        746100       0      738065    8035
# 4        851404       1      839100   12303
# 5         99358       3       98174    1181
# 6       1177768       8     1163614   14146
# 7         11591       0       11587       4
# 8       2007313      10     1980781   26522
# 9        259110      15      255082    4013
# 10      1277615      11     1266561   11043
# 11      1056655      38     1045903   10714
# 12       312692      14      308465    4213
# 13       479444      10      474649    4785
# 14       442574       0      437243    5331
# 15      4072536     123     4032105   40308
# 16      6829249    1300     6756379   71570
# 17        29417       1       29185     231
# 18        11415       0       11363      52
# 19      1054934       2     1044155   10777
# ...

# %%
df.iloc[0:3,[1,2,3]]
# Out:
#    Total Cases  Active  Discharged
# 0        10747       0       10618
# 1      2339078       7     2324338
# 2        66891       0       66595

# %%
df.iloc[[1,2,5],[1,2,5]]
# Out:
#    Total Cases  Active  Active Ratio
# 1      2339078       7           0.0
# 2        66891       0           0.0
# 5        99358       3           0.0

# %%
df.loc[1:5]
# Out:
#            State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1     Andhra Pradesh      2339078       7     2324338   14733           0.0
# 2  Arunachal Pradesh        66891       0       66595     296           0.0
# 3              Assam       746100       0      738065    8035           0.0
# 4              Bihar       851404       1      839100   12303           0.0
# 5         Chandigarh        99358       3       98174    1181           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.55         1.45    40100376
# 5            98.81         1.19    30501026

# %%
df.sort_values(["Active","Discharged"])
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10747       0       10618
# 18                               Lakshadweep        11415       0       11363
# 7   Dadra and Nagar Haveli and Daman and Diu        11591       0       11587
# 24                                  Nagaland        35986       0       35204
# 2                          Arunachal Pradesh        66891       0       66595
# 32                                   Tripura       108034       0      107094
# 21                                   Manipur       139924       0      137775
# 23                                   Mizoram       238964       0      238238
# 14                                 Jharkhand       442574       0      437243
# 3                                      Assam       746100       0      738065
# 17                                    Ladakh        29417       1       29185
# ...

# %%
df["Total Members"]=df["Discharged"]+df["Deaths"]+df["Active"]

# %%
df.loc[1:4]
# Out:
#            State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1     Andhra Pradesh      2339078       7     2324338   14733           0.0
# 2  Arunachal Pradesh        66891       0       66595     296           0.0
# 3              Assam       746100       0      738065    8035           0.0
# 4              Bihar       851404       1      839100   12303           0.0
#
#    Discharge Ratio  Death Ratio  Population  Total Members
# 1            99.37         0.63   128500364        2339078
# 2            99.56         0.44      658019          66891
# 3            98.92         1.08      290492         746100
# 4            98.55         1.45    40100376         851404

# %%
df.drop(columns="Discharge Ratio",inplace=True)

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10747       0       10618
# 1                             Andhra Pradesh      2339078       7     2324338
# 2                          Arunachal Pradesh        66891       0       66595
# 3                                      Assam       746100       0      738065
# 4                                      Bihar       851404       1      839100
# 5                                 Chandigarh        99358       3       98174
# 6                               Chhattisgarh      1177768       8     1163614
# 7   Dadra and Nagar Haveli and Daman and Diu        11591       0       11587
# 8                                      Delhi      2007313      10     1980781
# 9                                        Goa       259110      15      255082
# 10                                   Gujarat      1277615      11     1266561
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# dtype: bool

# %%
df.loc[1:4]
# Out:
#            State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1     Andhra Pradesh      2339078       7     2324338   14733           0.0
# 2  Arunachal Pradesh        66891       0       66595     296           0.0
# 3              Assam       746100       0      738065    8035           0.0
# 4              Bihar       851404       1      839100   12303           0.0
#
#    Death Ratio  Population  Total Members
# 1         0.63   128500364        2339078
# 2         0.44      658019          66891
# 3         1.08      290492         746100
# 4         1.45    40100376         851404

# %%
df.loc[df["Active"]>50]
# Out:
#       State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 15    Karnataka      4072536     123     4032105   40308          0.00
# 16       Kerala      6829249    1300     6756379   71570          0.02
# 20  Maharashtra      8136945     134     7988392  148419          0.00
# 25       Odisha      1336595      84     1327306    9205          0.01
# 26   Puducherry       175636      73      173588    1975          0.04
# 30   Tamil Nadu      3594573      58     3556466   38049          0.00
#
#     Death Ratio  Population  Total Members
# 15         0.99     1711947        4072536
# 16         1.05    91702478        6829249
# 20         1.82      399001        8136945
# 25         0.69    19301096        1336595
# 26         1.12     2073074         175636
# 30         1.06    35998752        3594573

# %%
df.loc[(df["Active"]>50) & (df["Active"]<150)]
# Out:
#       State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 15    Karnataka      4072536     123     4032105   40308          0.00
# 20  Maharashtra      8136945     134     7988392  148419          0.00
# 25       Odisha      1336595      84     1327306    9205          0.01
# 26   Puducherry       175636      73      173588    1975          0.04
# 30   Tamil Nadu      3594573      58     3556466   38049          0.00
#
#     Death Ratio  Population  Total Members
# 15         0.99     1711947        4072536
# 20         1.82      399001        8136945
# 25         0.69    19301096        1336595
# 26         1.12     2073074         175636
# 30         1.06    35998752        3594573

# %%
df.loc[df["State/UTs"].str.contains("s")]
# Out:
#             State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1      Andhra Pradesh      2339078       7     2324338   14733          0.00
# 2   Arunachal Pradesh        66891       0       66595     296          0.00
# 3               Assam       746100       0      738065    8035          0.00
# 6        Chhattisgarh      1177768       8     1163614   14146          0.00
# 12   Himachal Pradesh       312692      14      308465    4213          0.00
# 13  Jammu and Kashmir       479444      10      474649    4785          0.00
# 18        Lakshadweep        11415       0       11363      52          0.00
# 19     Madhya Pradesh      1054934       2     1044155   10777          0.00
# 20        Maharashtra      8136945     134     7988392  148419          0.00
# 25             Odisha      1336595      84     1327306    9205          0.01
# 28          Rajasthan      1315564       5     1305906    9653          0.00
# ...

# %%
df.loc[df["State/UTs"].str.startswith("A")]
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10747       0       10618     129           0.0
# 1       Andhra Pradesh      2339078       7     2324338   14733           0.0
# 2    Arunachal Pradesh        66891       0       66595     296           0.0
# 3                Assam       746100       0      738065    8035           0.0
#
#    Death Ratio  Population  Total Members
# 0         1.20   100896618          10747
# 1         0.63   128500364        2339078
# 2         0.44      658019          66891
# 3         1.08      290492         746100

# %%
df.loc[df["State/UTs"].str.endswith("a")]
# Out:
#       State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 9           Goa       259110      15      255082    4013          0.01
# 11      Haryana      1056655      38     1045903   10714          0.00
# 15    Karnataka      4072536     123     4032105   40308          0.00
# 16       Kerala      6829249    1300     6756379   71570          0.02
# 20  Maharashtra      8136945     134     7988392  148419          0.00
# 22    Meghalaya        96786       1       95161    1624          0.00
# 25       Odisha      1336595      84     1327306    9205          0.01
# 31    Telengana       841453      27      837315    4111          0.00
# 32      Tripura       108034       0      107094     940          0.00
#
#     Death Ratio  Population  Total Members
# 9          1.55     3772103         259110
# 11         1.01     7503010        1056655
# 15         0.99     1711947        4072536
# 16         1.05    91702478        6829249
# ...
